# %% [markdown]
# # What is the probability that a randomly selected movie has a score 8.0?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution of movie scores
mean_score = 7.5       # example mean
std_dev_score = 1.0    # example std deviation

# Target score and interval width for probability calculation
target_score = 8.0
interval_width = 0.1
lower_bound = target_score - interval_width / 2
upper_bound = target_score + interval_width / 2

# 1. Theoretical probability of score within the interval
theoretical_prob = norm.cdf(upper_bound, mean_score, std_dev_score) - norm.cdf(lower_bound, mean_score, std_dev_score)
print(f"Theoretical probability of score between {lower_bound} and {upper_bound}: {theoretical_prob:.4f}")

# 2. Generate sample data (simulate movie scores)
np.random.seed(0)
sample_size = 10000
sample_scores = np.random.normal(mean_score, std_dev_score, sample_size)

# Empirical probability from sample data
count_in_interval = np.sum((sample_scores >= lower_bound) & (sample_scores <= upper_bound))
empirical_prob = count_in_interval / sample_size
print(f"Empirical probability of score between {lower_bound} and {upper_bound}: {empirical_prob:.4f}")

# Plot histogram of sample scores
plt.hist(sample_scores, bins=30, color='skyblue', edgecolor='black', alpha=0.7, label='Sample Scores')

# Highlight the interval around the target score
plt.axvspan(lower_bound, upper_bound, color='orange', alpha=0.4, label=f'Interval [{lower_bound:.2f}, {upper_bound:.2f}]')

# Add labels and title
plt.title('Histogram of Movie Scores')
plt.xlabel('Movie Score')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()
# Out:
# Theoretical probability of score between 7.95 and 8.05: 0.0352
# Empirical probability of score between 7.95 and 8.05: 0.0329

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data: replace this with your actual data array
data = np.array([7.2, 8.1, 6.9, 7.8, 8.3, 7.5, 7.0, 8.0, 7.4, 7.9])

# Calculate mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

print(f"Mean: {mean:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")

# Plot histogram
plt.hist(data, bins=5, color='lightblue', edgecolor='black', alpha=0.7)

# Add vertical lines for mean and std deviation
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean = {mean:.2f}')
plt.axvline(mean + std_dev, color='green', linestyle='dashed', linewidth=2, label=f'Mean + 1 SD = {mean + std_dev:.2f}')
plt.axvline(mean - std_dev, color='green', linestyle='dashed', linewidth=2, label=f'Mean - 1 SD = {mean - std_dev:.2f}')

# Add labels and legend
plt.title('Histogram with Mean and Standard Deviation')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.show()
# Out:
# Mean: 7.61
# Standard Deviation: 0.46

# %%
import numpy as np

# Example data: replace with your actual data
data = np.array([7.2, 8.1, 6.9, 7.8, 8.3, 7.5, 7.0, 8.0, 7.4, 7.9])

# Calculate mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

# Calculate z-scores
z_scores = (data - mean) / std_dev

print("Data:", data)
print(f"Mean: {mean:.2f}, Standard Deviation: {std_dev:.2f}")
print("Z-scores:", z_scores)
# Out:
# Data: [7.2 8.1 6.9 7.8 8.3 7.5 7.  8.  7.4 7.9]
# Mean: 7.61, Standard Deviation: 0.46
# Z-scores: [-0.89704584  1.07207918 -1.55342085  0.41570417  1.50966251 -0.24067084
#  -1.33462918  0.85328751 -0.4594625   0.63449584]
